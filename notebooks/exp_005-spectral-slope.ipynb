# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/competitions/playground-series-s6e6/sample_submission.csv
# /kaggle/input/competitions/playground-series-s6e6/train.csv
# /kaggle/input/competitions/playground-series-s6e6/test.csv

# %% [markdown]
# # Playground Series S6E6 Kaggle Notebook Cells

# %% [markdown]
# ## 1. Import + Config

# %%
import os
import gc
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")


class CFG:
    competition = "playground-series-s6e6"
    exp_id = "exp_005_spectral-slope"
    parent_exp_id = "exp_04_colour-indices"
    note = "Added new features of spectral slope"

    data_dir_candidates = [
        Path("/kaggle/input/playground-series-s6e6"),
        Path("/kaggle/input/competitions/playground-series-s6e6"),
    ]
    output_path = Path("submission.csv")

    seed = 42
    n_splits = 5
    models = ["lgbm", "xgb", "cat"]
    model_weights = None  # None means simple average.

    num_boost_round = 5000
    early_stopping_rounds = 100
    verbose_eval = 100

    lgbm_params = {
        "objective": "multiclass",
        "metric": "multi_logloss",
        "learning_rate": 0.03,
        "num_leaves": 64,
        "max_depth": -1,
        "bagging_fraction": 0.85,
        "bagging_freq": 1,
        "feature_fraction": 0.85,
        "reg_alpha": 0.1,
        "reg_lambda": 1.0,
        "min_child_samples": 30,
        "seed": seed,
        "n_jobs": -1,
        "verbosity": -1,
        "device": "gpu",
    }

    xgb_params = {
        "objective": "multi:softprob",
        "eval_metric": "mlogloss",
        "eta": 0.03,
        "max_depth": 7,
        "subsample": 0.85,
        "colsample_bytree": 0.85,
        "lambda": 1.0,
        "alpha": 0.1,
        "seed": seed,
        "tree_method": "hist",
        "device": "cuda",
    }

    cat_params = {
        "loss_function": "MultiClass",
        "eval_metric": "MultiClass",
        "iterations": num_boost_round,
        "learning_rate": 0.03,
        "depth": 7,
        "l2_leaf_reg": 3.0,
        "random_seed": seed,
        "task_type": "GPU",
        "devices": "0",
        "verbose": verbose_eval,
        "allow_writing_files": False,
    }


def seed_everything(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)


seed_everything(CFG.seed)

# %% [markdown]
# ## 2. Data Loading

# %%
def find_data_dir(candidates):
    for data_dir in candidates:
        if (data_dir / "train.csv").exists():
            return data_dir
    raise FileNotFoundError("Could not find train.csv. Check Kaggle input settings.")


CFG.data_dir = find_data_dir(CFG.data_dir_candidates)

train = pd.read_csv(CFG.data_dir / "train.csv")
test = pd.read_csv(CFG.data_dir / "test.csv")
sample_submission = pd.read_csv(CFG.data_dir / "sample_submission.csv")

id_col = "id" if "id" in train.columns else sample_submission.columns[0]
target_col = [c for c in sample_submission.columns if c != id_col][0]

print("data_dir:", CFG.data_dir)
print("train:", train.shape)
print("test :", test.shape)
print("target:", target_col)
print(train.head())
# Out:
# data_dir: /kaggle/input/competitions/playground-series-s6e6
# train: (577347, 12)
# test : (247435, 11)
# target: class
#    id       alpha      delta          u          g          r          i  \
# 0   0  147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   1  127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   2  179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   3  225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   4  141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#            z  redshift spectral_type galaxy_population   class
# 0  18.621057  0.408982             M      Red_Sequence  GALAXY
# 1  16.786433  0.157976             M      Red_Sequence  GALAXY
# 2  20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3  17.914952  0.536099             M      Red_Sequence  GALAXY
# 4  17.616185  0.555761             M      Red_Sequence  GALAXY

# %% [markdown]
# ## 3. Feature Generation Hooks

# %%
def add_basic_features(df):
    # Future extraction point: src/features.py
    df = df.copy()

    feature_cols = [c for c in df.columns if c not in [id_col, target_col]]
    num_cols = [c for c in feature_cols if pd.api.types.is_numeric_dtype(df[c])]

    if len(num_cols) > 0:
        df["num_missing_count"] = df[num_cols].isna().sum(axis=1)
        df["num_zero_count"] = (df[num_cols] == 0).sum(axis=1)

    # Vectorisation
    if "alpha" in df.columns:
        alpha_rad = np.radians(df["alpha"])
        df["alpha_sin"] = np.sin(alpha_rad)
        df["alpha_cos"] = np.cos(alpha_rad)

    if "delta" in df.columns:
        delta_rad = np.radians(df["delta"])
        df["delta_sin"] = np.sin(delta_rad)
        df["delta_cos"] = np.cos(delta_rad)

    if {"alpha_sin", "alpha_cos", "delta_sin", "delta_cos"}.issubset(df.columns):
        df["coord_x"] = df["delta_cos"] * df["alpha_cos"]
        df["coord_y"] = df["delta_cos"] * df["alpha_sin"]
        df["coord_z"] = df["delta_sin"]

    # Colour Indices
    df["u_g"] = df["u"] - df["g"]
    df["g_r"] = df["g"] - df["r"]
    df["r_i"] = df["r"] - df["i"]
    df["i_z"] = df["i"] - df["z"]

    # Spectral Slope
    df["u_z"] = df["u"] - df["z"]
    df["u_i"] = df["u"] - df["i"]
    df["g_z"] = df["g"] - df["z"]

    return df


def prepare_features(train_df, test_df):
    train_df = add_basic_features(train_df)
    test_df = add_basic_features(test_df)

    features = [c for c in train_df.columns if c not in [id_col, target_col]]
    all_df = pd.concat([train_df[features], test_df[features]], axis=0, ignore_index=True)

    cat_cols = [c for c in features if all_df[c].dtype == "object" or str(all_df[c].dtype) == "category"]
    num_cols = [c for c in features if c not in cat_cols]

    for c in num_cols:
        median = all_df[c].median()
        train_df[c] = train_df[c].fillna(median)
        test_df[c] = test_df[c].fillna(median)

    for c in cat_cols:
        train_df[c] = train_df[c].astype("string").fillna("__MISSING__")
        test_df[c] = test_df[c].astype("string").fillna("__MISSING__")

        cats = pd.Index(pd.concat([train_df[c], test_df[c]], axis=0).unique())
        train_df[c] = pd.Categorical(train_df[c], categories=cats)
        test_df[c] = pd.Categorical(test_df[c], categories=cats)

    return train_df, test_df, features, cat_cols


train_fe, test_fe, features, cat_cols = prepare_features(train, test)

print("n_features:", len(features))
print("categorical:", cat_cols)
# Out:
# n_features: 26
# categorical: ['spectral_type', 'galaxy_population']

# %% [markdown]
# ## 4. Validation

# %%
def encode_target(values):
    classes = pd.Index(pd.unique(values))
    class_to_id = {label: i for i, label in enumerate(classes)}
    encoded = pd.Series(values).map(class_to_id).to_numpy()
    return encoded, classes


def make_stratified_folds(y, n_splits, seed):
    rng = np.random.default_rng(seed)
    fold_indices = [[] for _ in range(n_splits)]

    for cls in np.unique(y):
        cls_idx = np.where(y == cls)[0]
        rng.shuffle(cls_idx)
        for fold, part in enumerate(np.array_split(cls_idx, n_splits)):
            fold_indices[fold].extend(part.tolist())

    all_idx = np.arange(len(y))
    folds = []
    for valid_idx in fold_indices:
        valid_idx = np.array(sorted(valid_idx))
        train_idx = np.setdiff1d(all_idx, valid_idx)
        folds.append((train_idx, valid_idx))
    return folds


def accuracy(y_true, proba):
    return float((y_true == proba.argmax(axis=1)).mean())


def multiclass_log_loss(y_true, proba):
    proba = np.clip(proba, 1e-15, 1 - 1e-15)
    return float(-np.mean(np.log(proba[np.arange(len(y_true)), y_true])))


y, classes = encode_target(train_fe[target_col])
n_classes = len(classes)
folds = make_stratified_folds(y, CFG.n_splits, CFG.seed)

print("classes:", list(classes))
print("folds:", len(folds))
# Out:
# classes: ['GALAXY', 'QSO', 'STAR']
# folds: 5

# %% [markdown]
# ## 5. Training

# %%
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier, Pool


def encode_categoricals(df):
    out = df.copy()
    for c in cat_cols:
        out[c] = out[c].cat.codes.astype("int32")
    return out


def train_lgbm_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    params = CFG.lgbm_params.copy()
    params["num_class"] = n_classes

    train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=cat_cols, free_raw_data=False)
    valid_data = lgb.Dataset(X_valid, label=y_valid, categorical_feature=cat_cols, free_raw_data=False)

    model = lgb.train(
        params,
        train_data,
        num_boost_round=CFG.num_boost_round,
        valid_sets=[valid_data],
        valid_names=["valid"],
        callbacks=[
            lgb.early_stopping(CFG.early_stopping_rounds, verbose=False),
            lgb.log_evaluation(CFG.verbose_eval),
        ],
    )
    valid_pred = model.predict(X_valid, num_iteration=model.best_iteration)
    test_pred = model.predict(X_test, num_iteration=model.best_iteration)
    return model, valid_pred, test_pred, model.best_iteration


def train_xgb_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    params = CFG.xgb_params.copy()
    params["num_class"] = n_classes

    X_train_xgb = encode_categoricals(X_train)
    X_valid_xgb = encode_categoricals(X_valid)
    X_test_xgb = encode_categoricals(X_test)

    dtrain = xgb.DMatrix(X_train_xgb, label=y_train)
    dvalid = xgb.DMatrix(X_valid_xgb, label=y_valid)
    dtest = xgb.DMatrix(X_test_xgb)

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=CFG.num_boost_round,
        evals=[(dvalid, "valid")],
        early_stopping_rounds=CFG.early_stopping_rounds,
        verbose_eval=CFG.verbose_eval,
    )
    valid_pred = model.predict(dvalid, iteration_range=(0, model.best_iteration + 1))
    test_pred = model.predict(dtest, iteration_range=(0, model.best_iteration + 1))
    return model, valid_pred, test_pred, model.best_iteration


def to_catboost_frame(df):
    out = df.copy()
    for c in cat_cols:
        out[c] = out[c].astype(str)
    return out


def train_cat_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    cat_features = [X_train.columns.get_loc(c) for c in cat_cols]

    X_train_cat = to_catboost_frame(X_train)
    X_valid_cat = to_catboost_frame(X_valid)
    X_test_cat = to_catboost_frame(X_test)

    train_pool = Pool(X_train_cat, y_train, cat_features=cat_features)
    valid_pool = Pool(X_valid_cat, y_valid, cat_features=cat_features)
    test_pool = Pool(X_test_cat, cat_features=cat_features)

    model = CatBoostClassifier(**CFG.cat_params)
    model.fit(
        train_pool,
        eval_set=valid_pool,
        early_stopping_rounds=CFG.early_stopping_rounds,
        use_best_model=True,
    )
    valid_pred = model.predict_proba(valid_pool)
    test_pred = model.predict_proba(test_pool)
    return model, valid_pred, test_pred, model.get_best_iteration()


def train_model(model_name):
    oof = np.zeros((len(train_fe), n_classes), dtype=np.float32)
    test_pred = np.zeros((len(test_fe), n_classes), dtype=np.float32)
    fold_logs = []

    print(f"\n===== {model_name} =====")
    for fold, (tr_idx, va_idx) in enumerate(folds, 1):
        X_tr = train_fe.iloc[tr_idx][features]
        y_tr = y[tr_idx]
        X_va = train_fe.iloc[va_idx][features]
        y_va = y[va_idx]
        X_te = test_fe[features]

        if model_name == "lgbm":
            model, valid_pred, test_fold_pred, best_iteration = train_lgbm_fold(X_tr, y_tr, X_va, y_va, X_te)
        elif model_name == "xgb":
            model, valid_pred, test_fold_pred, best_iteration = train_xgb_fold(X_tr, y_tr, X_va, y_va, X_te)
        elif model_name == "cat":
            model, valid_pred, test_fold_pred, best_iteration = train_cat_fold(X_tr, y_tr, X_va, y_va, X_te)
        else:
            raise ValueError(f"Unknown model: {model_name}")

        oof[va_idx] = valid_pred
        test_pred += test_fold_pred / CFG.n_splits

        fold_acc = accuracy(y_va, valid_pred)
        fold_ll = multiclass_log_loss(y_va, valid_pred)
        fold_logs.append({
            "fold": fold,
            "accuracy": fold_acc,
            "logloss": fold_ll,
            "best_iteration": int(best_iteration) if best_iteration is not None else None,
        })
        print(f"{model_name} fold {fold}: accuracy={fold_acc:.6f}, logloss={fold_ll:.6f}, best_iteration={best_iteration}")

        del model, X_tr, X_va, X_te
        gc.collect()

    cv_acc = accuracy(y, oof)
    cv_ll = multiclass_log_loss(y, oof)
    print(f"{model_name} CV: accuracy={cv_acc:.6f}, logloss={cv_ll:.6f}")

    return {
        "name": model_name,
        "oof": oof,
        "test_pred": test_pred,
        "cv_accuracy": cv_acc,
        "cv_logloss": cv_ll,
        "folds": fold_logs,
    }


model_results = []
for model_name in CFG.models:
    model_results.append(train_model(model_name))
# Out:
# ===== lgbm =====
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [100]	valid's multi_logloss: 0.116396
# [200]	valid's multi_logloss: 0.0929189
# [300]	valid's multi_logloss: 0.088673
# [400]	valid's multi_logloss: 0.0870852
# [500]	valid's multi_logloss: 0.0861238
# [600]	valid's multi_logloss: 0.0856232
# [700]	valid's multi_logloss: 0.0852778
# [800]	valid's multi_logloss: 0.0849982
# [900]	valid's multi_logloss: 0.0847957
# [1000]	valid's multi_logloss: 0.0846469
# [1100]	valid's multi_logloss: 0.0845769
# [1200]	valid's multi_logloss: 0.0844825
# [1300]	valid's multi_logloss: 0.0845016
# lgbm fold 1: accuracy=0.969888, logloss=0.084473, best_iteration=1222
# [100]	valid's multi_logloss: 0.115997
# [200]	valid's multi_logloss: 0.0925869
# [300]	valid's multi_logloss: 0.0888599
# [400]	valid's multi_logloss: 0.0873903
# [500]	valid's multi_logloss: 0.0865537
# [600]	valid's multi_logloss: 0.0859681
# [700]	valid's multi_logloss: 0.0856395
# [800]	valid's multi_logloss: 0.085336
# [900]	valid's multi_logloss: 0.0851323
# [1000]	valid's multi_logloss: 0.0850403
# [1100]	valid's multi_logloss: 0.0849943
# [1200]	valid's multi_logloss: 0.0849941
# lgbm fold 2: accuracy=0.970036, logloss=0.084957, best_iteration=1156
# [100]	valid's multi_logloss: 0.118403
# [200]	valid's multi_logloss: 0.0944669
# [300]	valid's multi_logloss: 0.0902204
# [400]	valid's multi_logloss: 0.0885609
# [500]	valid's multi_logloss: 0.087606
# [600]	valid's multi_logloss: 0.0870321
# [700]	valid's multi_logloss: 0.0865301
# [800]	valid's multi_logloss: 0.0862738
# [900]	valid's multi_logloss: 0.0860643
# [1000]	valid's multi_logloss: 0.0859483
# [1100]	valid's multi_logloss: 0.0858673
# [1200]	valid's multi_logloss: 0.0858227
# [1300]	valid's multi_logloss: 0.0858143
# [1400]	valid's multi_logloss: 0.0858174
# lgbm fold 3: accuracy=0.968797, logloss=0.085787, best_iteration=1327
# [100]	valid's multi_logloss: 0.11885
# [200]	valid's multi_logloss: 0.0963058
# [300]	valid's multi_logloss: 0.0923655
# [400]	valid's multi_logloss: 0.0909836
# [500]	valid's multi_logloss: 0.0901656
# [600]	valid's multi_logloss: 0.0895556
# [700]	valid's multi_logloss: 0.0892919
# [800]	valid's multi_logloss: 0.0891045
# [900]	valid's multi_logloss: 0.0889545
# [1000]	valid's multi_logloss: 0.0888905
# [1100]	valid's multi_logloss: 0.0888305
# [1200]	valid's multi_logloss: 0.088767
# [1300]	valid's multi_logloss: 0.0887866
# lgbm fold 4: accuracy=0.968580, logloss=0.088760, best_iteration=1204
# [100]	valid's multi_logloss: 0.117763
# [200]	valid's multi_logloss: 0.0938739
# [300]	valid's multi_logloss: 0.0896039
# [400]	valid's multi_logloss: 0.0879922
# [500]	valid's multi_logloss: 0.0870973
# [600]	valid's multi_logloss: 0.0865513
# [700]	valid's multi_logloss: 0.0861897
# [800]	valid's multi_logloss: 0.0859734
# [900]	valid's multi_logloss: 0.0857762
# [1000]	valid's multi_logloss: 0.0856291
# [1100]	valid's multi_logloss: 0.0855558
# [1200]	valid's multi_logloss: 0.0854663
# [1300]	valid's multi_logloss: 0.0854389
# [1400]	valid's multi_logloss: 0.0854024
# [1500]	valid's multi_logloss: 0.0854507
# lgbm fold 5: accuracy=0.969827, logloss=0.085399, best_iteration=1406
# lgbm CV: accuracy=0.969426, logloss=0.085875
#
# ===== xgb =====
# [0]	valid-mlogloss:0.84258
# [100]	valid-mlogloss:0.13784
# [200]	valid-mlogloss:0.10351
# [300]	valid-mlogloss:0.09616
# [400]	valid-mlogloss:0.09250
# [500]	valid-mlogloss:0.09012
# [600]	valid-mlogloss:0.08845
# [700]	valid-mlogloss:0.08733
# [800]	valid-mlogloss:0.08656
# [900]	valid-mlogloss:0.08600
# [1000]	valid-mlogloss:0.08560
# [1100]	valid-mlogloss:0.08528
# [1200]	valid-mlogloss:0.08506
# [1300]	valid-mlogloss:0.08487
# [1400]	valid-mlogloss:0.08479
# [1500]	valid-mlogloss:0.08472
# [1600]	valid-mlogloss:0.08466
# [1700]	valid-mlogloss:0.08467
# [1725]	valid-mlogloss:0.08466
# xgb fold 1: accuracy=0.969602, logloss=0.084651, best_iteration=1625
# [0]	valid-mlogloss:0.84255
# [100]	valid-mlogloss:0.13705
# [200]	valid-mlogloss:0.10250
# [300]	valid-mlogloss:0.09534
# [400]	valid-mlogloss:0.09199
# [500]	valid-mlogloss:0.08960
# [600]	valid-mlogloss:0.08827
# [700]	valid-mlogloss:0.08722
# [800]	valid-mlogloss:0.08649
# [900]	valid-mlogloss:0.08604
# [1000]	valid-mlogloss:0.08574
# [1100]	valid-mlogloss:0.08541
# [1200]	valid-mlogloss:0.08518
# [1300]	valid-mlogloss:0.08505
# [1400]	valid-mlogloss:0.08491
# [1500]	valid-mlogloss:0.08486
# [1600]	valid-mlogloss:0.08487
# [1666]	valid-mlogloss:0.08489
# xgb fold 2: accuracy=0.970252, logloss=0.084843, best_iteration=1566
# [0]	valid-mlogloss:0.84265
# [100]	valid-mlogloss:0.13961
# [200]	valid-mlogloss:0.10510
# [300]	valid-mlogloss:0.09792
# [400]	valid-mlogloss:0.09408
# [500]	valid-mlogloss:0.09155
# [600]	valid-mlogloss:0.08975
# [700]	valid-mlogloss:0.08857
# [800]	valid-mlogloss:0.08773
# [900]	valid-mlogloss:0.08714
# [1000]	valid-mlogloss:0.08678
# [1100]	valid-mlogloss:0.08642
# [1200]	valid-mlogloss:0.08614
# [1300]	valid-mlogloss:0.08599
# [1400]	valid-mlogloss:0.08590
# [1500]	valid-mlogloss:0.08585
# [1600]	valid-mlogloss:0.08579
# [1700]	valid-mlogloss:0.08581
# [1710]	valid-mlogloss:0.08582
# xgb fold 3: accuracy=0.968667, logloss=0.085783, best_iteration=1610
# [0]	valid-mlogloss:0.84262
# [100]	valid-mlogloss:0.13969
# [200]	valid-mlogloss:0.10604
# [300]	valid-mlogloss:0.09892
# [400]	valid-mlogloss:0.09559
# [500]	valid-mlogloss:0.09340
# [600]	valid-mlogloss:0.09195
# [700]	valid-mlogloss:0.09101
# [800]	valid-mlogloss:0.09041
# [900]	valid-mlogloss:0.08981
# [1000]	valid-mlogloss:0.08949
# [1100]	valid-mlogloss:0.08926
# [1200]	valid-mlogloss:0.08914
# [1300]	valid-mlogloss:0.08903
# [1400]	valid-mlogloss:0.08896
# [1500]	valid-mlogloss:0.08897
# [1553]	valid-mlogloss:0.08899
# xgb fold 4: accuracy=0.968468, logloss=0.088947, best_iteration=1453
# [0]	valid-mlogloss:0.84269
# [100]	valid-mlogloss:0.13891
# [200]	valid-mlogloss:0.10399
# [300]	valid-mlogloss:0.09635
# [400]	valid-mlogloss:0.09287
# [500]	valid-mlogloss:0.09055
# [600]	valid-mlogloss:0.08885
# [700]	valid-mlogloss:0.08778
# [800]	valid-mlogloss:0.08708
# [900]	valid-mlogloss:0.08658
# [1000]	valid-mlogloss:0.08624
# [1100]	valid-mlogloss:0.08597
# [1200]	valid-mlogloss:0.08578
# [1300]	valid-mlogloss:0.08560
# [1400]	valid-mlogloss:0.08551
# [1500]	valid-mlogloss:0.08544
# [1600]	valid-mlogloss:0.08541
# [1700]	valid-mlogloss:0.08542
# [1740]	valid-mlogloss:0.08543
# xgb fold 5: accuracy=0.969654, logloss=0.085398, best_iteration=1640
# xgb CV: accuracy=0.969329, logloss=0.085924
#
# ===== cat =====
# 0:	learn: 1.0488114	test: 1.0487865	best: 1.0487865 (0)	total: 6.32s	remaining: 8h 46m 28s
# 100:	learn: 0.1641327	test: 0.1635857	best: 0.1635857 (100)	total: 7.94s	remaining: 6m 24s
# 200:	learn: 0.1232508	test: 0.1228257	best: 0.1228257 (200)	total: 9.52s	remaining: 3m 47s
# 300:	learn: 0.1124223	test: 0.1124553	best: 0.1124553 (300)	total: 11.1s	remaining: 2m 53s
# 400:	learn: 0.1067652	test: 0.1073532	best: 0.1073532 (400)	total: 12.7s	remaining: 2m 25s
# 500:	learn: 0.1030250	test: 0.1041601	best: 0.1041601 (500)	total: 14.3s	remaining: 2m 7s
# 600:	learn: 0.1002466	test: 0.1019020	best: 0.1019020 (600)	total: 15.9s	remaining: 1m 56s
# 700:	learn: 0.0982043	test: 0.1003606	best: 0.1003606 (700)	total: 17.5s	remaining: 1m 47s
# 800:	learn: 0.0964835	test: 0.0990805	best: 0.0990805 (800)	total: 19s	remaining: 1m 39s
# 900:	learn: 0.0950021	test: 0.0980806	best: 0.0980806 (900)	total: 20.6s	remaining: 1m 33s
# 3800:	learn: 0.0770552	test: 0.0902001	best: 0.0901992 (3799)	total: 1m	remaining: 19.2s
# 3900:	learn: 0.0766910	test: 0.0901573	best: 0.0901573 (3900)	total: 1m 2s	remaining: 17.6s
# 4000:	learn: 0.0762780	test: 0.0900826	best: 0.0900821 (3999)	total: 1m 4s	remaining: 16s
# 4100:	learn: 0.0758971	test: 0.0900144	best: 0.0900132 (4099)	total: 1m 5s	remaining: 14.4s
# 4200:	learn: 0.0755459	test: 0.0899861	best: 0.0899849 (4199)	total: 1m 7s	remaining: 12.8s
# 4300:	learn: 0.0751820	test: 0.0899400	best: 0.0899400 (4300)	total: 1m 8s	remaining: 11.2s
# 4400:	learn: 0.0748170	test: 0.0899104	best: 0.0899092 (4397)	total: 1m 10s	remaining: 9.58s
# 4500:	learn: 0.0744463	test: 0.0898651	best: 0.0898605 (4477)	total: 1m 11s	remaining: 7.98s
# 4600:	learn: 0.0740954	test: 0.0898085	best: 0.0898085 (4600)	total: 1m 13s	remaining: 6.38s
# 4700:	learn: 0.0737634	test: 0.0897806	best: 0.0897785 (4689)	total: 1m 15s	remaining: 4.78s
# 4800:	learn: 0.0734212	test: 0.0897393	best: 0.0897380 (4798)	total: 1m 16s	remaining: 3.18s
# 4900:	learn: 0.0730674	test: 0.0897022	best: 0.0897021 (4894)	total: 1m 18s	remaining: 1.58s
# 4999:	learn: 0.0727256	test: 0.0896718	best: 0.0896704 (4991)	total: 1m 19s	remaining: 0us
# bestTest = 0.08967041798
# bestIteration = 4991
# Shrink model to first 4992 iterations.
# cat fold 2: accuracy=0.967827, logloss=0.089670, best_iteration=4991
# 0:	learn: 1.0489717	test: 1.0490387	best: 1.0490387 (0)	total: 19.6ms	remaining: 1m 37s
# 100:	learn: 0.1632490	test: 0.1648103	best: 0.1648103 (100)	total: 1.65s	remaining: 1m 20s
# 200:	learn: 0.1225135	test: 0.1246053	best: 0.1246053 (200)	total: 3.21s	remaining: 1m 16s
# 300:	learn: 0.1123170	test: 0.1148508	best: 0.1148508 (300)	total: 4.77s	remaining: 1m 14s
# 400:	learn: 0.1067490	test: 0.1095911	best: 0.1095911 (400)	total: 6.38s	remaining: 1m 13s
# 500:	learn: 0.1031081	test: 0.1063393	best: 0.1063393 (500)	total: 7.98s	remaining: 1m 11s
# 600:	learn: 0.1005386	test: 0.1041483	best: 0.1041483 (600)	total: 9.56s	remaining: 1m 9s
# 700:	learn: 0.0983486	test: 0.1023485	best: 0.1023485 (700)	total: 11.1s	remaining: 1m 8s
# 800:	learn: 0.0965663	test: 0.1009414	best: 0.1009414 (800)	total: 12.7s	remaining: 1m 6s
# 900:	learn: 0.0951484	test: 0.0998945	best: 0.0998945 (900)	total: 14.3s	remaining: 1m 5s
# 1000:	learn: 0.0939147	test: 0.0990481	best: 0.0990481 (1000)	total: 15.9s	remaining: 1m 3s
# 1100:	learn: 0.0926697	test: 0.0981925	best: 0.0981925 (1100)	total: 17.5s	remaining: 1m 2s
# 1200:	learn: 0.0916392	test: 0.0975131	best: 0.0975131 (1200)	total: 19.1s	remaining: 1m
# 4000:	learn: 0.0762389	test: 0.0917978	best: 0.0917978 (4000)	total: 1m 3s	remaining: 15.9s
# 4100:	learn: 0.0758624	test: 0.0917459	best: 0.0917456 (4098)	total: 1m 5s	remaining: 14.3s
# 4200:	learn: 0.0754633	test: 0.0916737	best: 0.0916737 (4200)	total: 1m 7s	remaining: 12.7s
# 4300:	learn: 0.0750901	test: 0.0916096	best: 0.0916076 (4297)	total: 1m 8s	remaining: 11.2s
# 4400:	learn: 0.0747278	test: 0.0915610	best: 0.0915610 (4400)	total: 1m 10s	remaining: 9.55s
# 4500:	learn: 0.0743720	test: 0.0914833	best: 0.0914833 (4500)	total: 1m 11s	remaining: 7.96s
# 4600:	learn: 0.0740220	test: 0.0914270	best: 0.0914260 (4599)	total: 1m 13s	remaining: 6.36s
# 4700:	learn: 0.0736792	test: 0.0913804	best: 0.0913804 (4700)	total: 1m 14s	remaining: 4.77s
# 4800:	learn: 0.0733294	test: 0.0913259	best: 0.0913247 (4794)	total: 1m 16s	remaining: 3.17s
# 4900:	learn: 0.0729588	test: 0.0912829	best: 0.0912812 (4894)	total: 1m 18s	remaining: 1.58s
# 4999:	learn: 0.0726314	test: 0.0912477	best: 0.0912477 (4998)	total: 1m 19s	remaining: 0us
# bestTest = 0.09124765057
# bestIteration = 4998
# Shrink model to first 4999 iterations.
# cat fold 3: accuracy=0.966519, logloss=0.091248, best_iteration=4998
# 0:	learn: 1.0488248	test: 1.0487950	best: 1.0487950 (0)	total: 18ms	remaining: 1m 29s
# 100:	learn: 0.1635510	test: 0.1648929	best: 0.1648929 (100)	total: 1.64s	remaining: 1m 19s
# 200:	learn: 0.1223470	test: 0.1248874	best: 0.1248874 (200)	total: 3.23s	remaining: 1m 17s
# 300:	learn: 0.1117428	test: 0.1149506	best: 0.1149506 (300)	total: 4.83s	remaining: 1m 15s
# 400:	learn: 0.1060245	test: 0.1097959	best: 0.1097959 (400)	total: 6.4s	remaining: 1m 13s
# 500:	learn: 0.1024785	test: 0.1067371	best: 0.1067371 (500)	total: 7.99s	remaining: 1m 11s
# 600:	learn: 0.0997250	test: 0.1044047	best: 0.1044047 (600)	total: 9.59s	remaining: 1m 10s
# 700:	learn: 0.0975618	test: 0.1027347	best: 0.1027347 (700)	total: 11.2s	remaining: 1m 8s
# 800:	learn: 0.0958430	test: 0.1014899	best: 0.1014899 (800)	total: 12.8s	remaining: 1m 7s
# 900:	learn: 0.0943686	test: 0.1004762	best: 0.1004762 (900)	total: 14.4s	remaining: 1m 5s
# 1000:	learn: 0.0930827	test: 0.0996689	best: 0.0996689 (1000)	total: 16s	remaining: 1m 3s
# 1100:	learn: 0.0919033	test: 0.0989359	best: 0.0989359 (1100)	total: 17.6s	remaining: 1m 2s
# 1200:	learn: 0.0908944	test: 0.0983561	best: 0.0983561 (1200)	total: 19.2s	remaining: 1m
# 1300:	learn: 0.0899766	test: 0.0978609	best: 0.0978609 (1300)	total: 20.8s	remaining: 59.1s
# 4100:	learn: 0.0751322	test: 0.0934684	best: 0.0934679 (4099)	total: 1m 5s	remaining: 14.3s
# 4200:	learn: 0.0747809	test: 0.0934150	best: 0.0934134 (4198)	total: 1m 6s	remaining: 12.7s
# 4300:	learn: 0.0744066	test: 0.0933588	best: 0.0933588 (4300)	total: 1m 8s	remaining: 11.1s
# 4400:	learn: 0.0740520	test: 0.0933245	best: 0.0933211 (4389)	total: 1m 10s	remaining: 9.53s
# 4500:	learn: 0.0736917	test: 0.0932892	best: 0.0932865 (4481)	total: 1m 11s	remaining: 7.94s
# 4600:	learn: 0.0733393	test: 0.0932626	best: 0.0932575 (4585)	total: 1m 13s	remaining: 6.35s
# 4700:	learn: 0.0729809	test: 0.0932180	best: 0.0932172 (4699)	total: 1m 14s	remaining: 4.76s
# 4800:	learn: 0.0726281	test: 0.0931982	best: 0.0931982 (4800)	total: 1m 16s	remaining: 3.17s
# 4900:	learn: 0.0723025	test: 0.0931957	best: 0.0931887 (4828)	total: 1m 18s	remaining: 1.58s
# 4999:	learn: 0.0719559	test: 0.0931535	best: 0.0931524 (4994)	total: 1m 19s	remaining: 0us
# bestTest = 0.09315239473
# bestIteration = 4994
# Shrink model to first 4995 iterations.
# cat fold 4: accuracy=0.966840, logloss=0.093152, best_iteration=4994
# 0:	learn: 1.0489755	test: 1.0490356	best: 1.0490356 (0)	total: 18.4ms	remaining: 1m 31s
# 100:	learn: 0.1634236	test: 0.1653127	best: 0.1653127 (100)	total: 1.65s	remaining: 1m 19s
# 200:	learn: 0.1225064	test: 0.1245148	best: 0.1245148 (200)	total: 3.2s	remaining: 1m 16s
# 300:	learn: 0.1118590	test: 0.1139924	best: 0.1139924 (300)	total: 4.77s	remaining: 1m 14s
# 400:	learn: 0.1064797	test: 0.1089182	best: 0.1089182 (400)	total: 6.34s	remaining: 1m 12s
# 500:	learn: 0.1028248	test: 0.1055446	best: 0.1055446 (500)	total: 7.92s	remaining: 1m 11s
# 600:	learn: 0.1001286	test: 0.1032294	best: 0.1032294 (600)	total: 9.51s	remaining: 1m 9s
# 700:	learn: 0.0979994	test: 0.1015043	best: 0.1015043 (700)	total: 11.1s	remaining: 1m 8s
# 800:	learn: 0.0962549	test: 0.1001680	best: 0.1001680 (800)	total: 12.7s	remaining: 1m 6s
# 900:	learn: 0.0948585	test: 0.0991811	best: 0.0991811 (900)	total: 14.3s	remaining: 1m 4s
# 1000:	learn: 0.0935728	test: 0.0982906	best: 0.0982906 (1000)	total: 15.8s	remaining: 1m 3s
# 1100:	learn: 0.0924203	test: 0.0975278	best: 0.0975278 (1100)	total: 17.5s	remaining: 1m 1s
# 1200:	learn: 0.0914575	test: 0.0969384	best: 0.0969384 (1200)	total: 19.1s	remaining: 1m
# 1300:	learn: 0.0905000	test: 0.0963954	best: 0.0963954 (1300)	total: 20.6s	remaining: 58.7s
# 1400:	learn: 0.0896944	test: 0.0959594	best: 0.0959594 (1400)	total: 22.2s	remaining: 57.1s
# 4200:	learn: 0.0754771	test: 0.0915399	best: 0.0915399 (4200)	total: 1m 6s	remaining: 12.7s
# 4300:	learn: 0.0750968	test: 0.0914563	best: 0.0914563 (4300)	total: 1m 8s	remaining: 11.1s
# 4400:	learn: 0.0747294	test: 0.0913884	best: 0.0913884 (4400)	total: 1m 9s	remaining: 9.52s
# 4500:	learn: 0.0743484	test: 0.0913171	best: 0.0913171 (4500)	total: 1m 11s	remaining: 7.93s
# 4600:	learn: 0.0739963	test: 0.0912656	best: 0.0912656 (4600)	total: 1m 13s	remaining: 6.34s
# 4700:	learn: 0.0736449	test: 0.0912267	best: 0.0912249 (4697)	total: 1m 14s	remaining: 4.75s
# 4800:	learn: 0.0733125	test: 0.0911946	best: 0.0911935 (4796)	total: 1m 16s	remaining: 3.16s
# 4900:	learn: 0.0729871	test: 0.0911626	best: 0.0911626 (4900)	total: 1m 17s	remaining: 1.57s
# 4999:	learn: 0.0726509	test: 0.0911362	best: 0.0911362 (4999)	total: 1m 19s	remaining: 0us
# bestTest = 0.09113616367
# bestIteration = 4999
# cat fold 5: accuracy=0.966952, logloss=0.091136, best_iteration=4999
# cat CV: accuracy=0.967049, logloss=0.091112

# %% [markdown]
# ## 6. Inference

# %%
if CFG.model_weights is None:
    weights = np.ones(len(model_results), dtype=np.float32) / len(model_results)
else:
    weights = np.array(CFG.model_weights, dtype=np.float32)
    weights = weights / weights.sum()

model_names = [result["name"] for result in model_results]
oof_proba = sum(w * result["oof"] for w, result in zip(weights, model_results))
test_proba = sum(w * result["test_pred"] for w, result in zip(weights, model_results))

cv_acc = accuracy(y, oof_proba)
cv_ll = multiclass_log_loss(y, oof_proba)

test_pred = classes.to_numpy()[test_proba.argmax(axis=1)]
pred_distribution = pd.Series(test_pred).value_counts(normalize=True).sort_index()

print("models:", model_names)
print("weights:", dict(zip(model_names, weights)))
print(f"ensemble CV: accuracy={cv_acc:.6f}, logloss={cv_ll:.6f}")
print(pred_distribution)
# Out:
# models: ['lgbm', 'xgb', 'cat']
# weights: {'lgbm': np.float32(0.33333334), 'xgb': np.float32(0.33333334), 'cat': np.float32(0.33333334)}
# ensemble CV: accuracy=0.969244, logloss=0.086233
# GALAXY    0.655340
# QSO       0.202243
# STAR      0.142417
# Name: proportion, dtype: float64

# %% [markdown]
# ## 7. Submission

# %%
submission = sample_submission.copy()
submission[target_col] = test_pred
submission.to_csv(CFG.output_path, index=False)

experiment_log = {
    "competition": CFG.competition,
    "exp_id": CFG.exp_id,
    "parent_exp_id": CFG.parent_exp_id,
    "note": CFG.note,
    "seed": CFG.seed,
    "n_splits": CFG.n_splits,
    "models": model_names,
    "model_weights": dict(zip(model_names, [float(w) for w in weights])),
    "model_scores": [
        {
            "name": result["name"],
            "cv_accuracy": float(result["cv_accuracy"]),
            "cv_logloss": float(result["cv_logloss"]),
            "folds": result["folds"],
        }
        for result in model_results
    ],
    "ensemble_cv_accuracy": float(cv_acc),
    "ensemble_cv_logloss": float(cv_ll),
    "n_features": len(features),
    "categorical_features": cat_cols,
    "gpu_settings": {
        "lgbm_device": CFG.lgbm_params.get("device"),
        "xgb_device": CFG.xgb_params.get("device"),
        "cat_task_type": CFG.cat_params.get("task_type"),
    },
    "output_path": str(CFG.output_path),
}

print(submission.head())
print("saved:", CFG.output_path)
experiment_log
# Out:
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: submission.csv
# {'competition': 'playground-series-s6e6',
#  'exp_id': 'exp_005_spectral-slope',
#  'parent_exp_id': 'exp_04_colour-indices',
#  'note': 'Added new features of spectral slope',
#  'seed': 42,
#  'n_splits': 5,
#  'models': ['lgbm', 'xgb', 'cat'],
#  'model_weights': {'lgbm': 0.3333333432674408,
#   'xgb': 0.3333333432674408,
#   'cat': 0.3333333432674408},
#  'model_scores': [{'name': 'lgbm',
#    'cv_accuracy': 0.9694256660206081,
#    'cv_logloss': 0.08587518334388733,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9698882826708236,
#      'logloss': 0.08447297237267547,
#      'best_iteration': 1222},
#     {'fold': 2,
#      'accuracy': 0.9700355070581104,
#      'logloss': 0.08495728898234511,
#      'best_iteration': 1156},
#     {'fold': 3,
#      'accuracy': 0.9687970901532865,
#      'logloss': 0.08578698931148711,
#      'best_iteration': 1327},
#     {'fold': 4,
#      'accuracy': 0.9685803115987841,
#      'logloss': 0.08875957722129403,
#      'best_iteration': 1204},
#     {'fold': 5,
#      'accuracy': 0.9698271382547545,
#      'logloss': 0.08539913049838234,
#      'best_iteration': 1406}]},
#   {'name': 'xgb',
#    'cv_accuracy': 0.9693286706261572,
#    'cv_logloss': 0.08592446893453598,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9696024941543258,
#      'logloss': 0.08465111255645752,
#      'best_iteration': 1625},
#     {'fold': 2,
#      'accuracy': 0.9702520135100026,
#      'logloss': 0.08484282344579697,
#      'best_iteration': 1566},
#     {'fold': 3,
#      'accuracy': 0.9686671862821512,
#      'logloss': 0.08578325808048248,
#      'best_iteration': 1610},
#     {'fold': 4,
#      'accuracy': 0.9684677272687907,
#      'logloss': 0.08894690126180649,
#      'best_iteration': 1453},
#     {'fold': 5,
#      'accuracy': 0.969653930093186,
#      'logloss': 0.08539827167987823,
#      'best_iteration': 1640}]},
#   {'name': 'cat',
#    'cv_accuracy': 0.9670492788565629,
#    'cv_logloss': 0.09111224114894867,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9671083398285268,
#      'logloss': 0.0903547507596867,
#      'best_iteration': 4983},
#     {'fold': 2,
#      'accuracy': 0.9678271412488092,
#      'logloss': 0.0896704239820562,
#      'best_iteration': 4991},
#     {'fold': 3,
#      'accuracy': 0.9665194422793799,
#      'logloss': 0.09124760178789719,
#      'best_iteration': 4998},
#     {'fold': 4,
#      'accuracy': 0.9668395846504256,
#      'logloss': 0.09315235077916947,
#      'best_iteration': 4994},
#     {'fold': 5,
#      'accuracy': 0.9669518827727163,
#      'logloss': 0.09113607981978321,
#      'best_iteration': 4999}]}],
#  'ensemble_cv_accuracy': 0.9692437996560128,
#  'ensemble_cv_logloss': 0.0862329751253128,
#  'n_features': 26,
#  'categorical_features': ['spectral_type', 'galaxy_population'],
#  'gpu_settings': {'lgbm_device': 'gpu',
#   'xgb_device': 'cuda',
#   'cat_task_type': 'GPU'},
#  'output_path': 'submission.csv'}
