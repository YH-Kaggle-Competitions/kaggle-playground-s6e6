# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/competitions/playground-series-s6e6/sample_submission.csv
# /kaggle/input/competitions/playground-series-s6e6/train.csv
# /kaggle/input/competitions/playground-series-s6e6/test.csv

# %% [markdown]
# # Playground Series S6E6 Kaggle Notebook Cells

# %% [markdown]
# ## 1. Import + Config

# %%
import os
import gc
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")


class CFG:
    competition = "playground-series-s6e6"
    exp_id = "exp_009_add-brightness-redshift-ratio"
    parent_exp_id = "exp_007_remove-cat-boost-and-xgb"
    note = "Remove vectorisation: x, y, z: coordinate"

    data_dir_candidates = [
        Path("/kaggle/input/playground-series-s6e6"),
        Path("/kaggle/input/competitions/playground-series-s6e6"),
    ]
    output_path = Path("submission.csv")

    seed = 42
    n_splits = 5
    models = ["lgbm", "xgb", "cat"]
    model_weights = None  # None means simple average.

    num_boost_round = 5000
    early_stopping_rounds = 100
    verbose_eval = 100

    lgbm_params = {
        "objective": "multiclass",
        "metric": "multi_logloss",
        "learning_rate": 0.03,
        "num_leaves": 64,
        "max_depth": -1,
        "bagging_fraction": 0.85,
        "bagging_freq": 1,
        "feature_fraction": 0.85,
        "reg_alpha": 0.1,
        "reg_lambda": 1.0,
        "min_child_samples": 30,
        "seed": seed,
        "n_jobs": -1,
        "verbosity": -1,
        "device": "gpu",
    }

    xgb_params = {
        "objective": "multi:softprob",
        "eval_metric": "mlogloss",
        "eta": 0.03,
        "max_depth": 7,
        "subsample": 0.85,
        "colsample_bytree": 0.85,
        "lambda": 1.0,
        "alpha": 0.1,
        "seed": seed,
        "tree_method": "hist",
        "device": "cuda",
    }

    cat_params = {
        "loss_function": "MultiClass",
        "eval_metric": "MultiClass",
        "iterations": num_boost_round,
        "learning_rate": 0.03,
        "depth": 7,
        "l2_leaf_reg": 3.0,
        "random_seed": seed,
        "task_type": "GPU",
        "devices": "0",
        "verbose": verbose_eval,
        "allow_writing_files": False,
    }


def seed_everything(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)


seed_everything(CFG.seed)

# %% [markdown]
# ## 2. Data Loading

# %%
def find_data_dir(candidates):
    for data_dir in candidates:
        if (data_dir / "train.csv").exists():
            return data_dir
    raise FileNotFoundError("Could not find train.csv. Check Kaggle input settings.")


CFG.data_dir = find_data_dir(CFG.data_dir_candidates)

train = pd.read_csv(CFG.data_dir / "train.csv")
test = pd.read_csv(CFG.data_dir / "test.csv")
sample_submission = pd.read_csv(CFG.data_dir / "sample_submission.csv")

id_col = "id" if "id" in train.columns else sample_submission.columns[0]
target_col = [c for c in sample_submission.columns if c != id_col][0]

print("data_dir:", CFG.data_dir)
print("train:", train.shape)
print("test :", test.shape)
print("target:", target_col)
print(train.head())
# Out:
# data_dir: /kaggle/input/competitions/playground-series-s6e6
# train: (577347, 12)
# test : (247435, 11)
# target: class
#    id       alpha      delta          u          g          r          i  \
# 0   0  147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   1  127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   2  179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   3  225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   4  141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#            z  redshift spectral_type galaxy_population   class
# 0  18.621057  0.408982             M      Red_Sequence  GALAXY
# 1  16.786433  0.157976             M      Red_Sequence  GALAXY
# 2  20.557366  2.823770           O/B        Blue_Cloud     QSO
# 3  17.914952  0.536099             M      Red_Sequence  GALAXY
# 4  17.616185  0.555761             M      Red_Sequence  GALAXY

# %% [markdown]
# ## 3. Feature Generation Hooks

# %%
def add_basic_features(df):
    # Future extraction point: src/features.py
    df = df.copy()

    feature_cols = [c for c in df.columns if c not in [id_col, target_col]]
    num_cols = [c for c in feature_cols if pd.api.types.is_numeric_dtype(df[c])]

    if len(num_cols) > 0:
        df["num_missing_count"] = df[num_cols].isna().sum(axis=1)
        df["num_zero_count"] = (df[num_cols] == 0).sum(axis=1)

    # Vectorisation
    if "alpha" in df.columns:
        alpha_rad = np.radians(df["alpha"])
        df["alpha_sin"] = np.sin(alpha_rad)
        df["alpha_cos"] = np.cos(alpha_rad)

    if "delta" in df.columns:
        delta_rad = np.radians(df["delta"])
        df["delta_sin"] = np.sin(delta_rad)
        df["delta_cos"] = np.cos(delta_rad)

    # Colour Indices
    df["u_g"] = df["u"] - df["g"]
    df["g_r"] = df["g"] - df["r"]
    df["r_i"] = df["r"] - df["i"]
    df["i_z"] = df["i"] - df["z"]

    # Spectral Slope
    df["u_z"] = df["u"] - df["z"]
    df["u_i"] = df["u"] - df["i"]
    df["g_z"] = df["g"] - df["z"]

    # Btightness Feature
    bands = ["u", "g", "r", "i", "z"]
    df["mag_mean"] = df[bands].mean(axis=1)
    df["mag_std"] = df[bands].std(axis=1)
    df["mag_range"] = df[bands].max(axis=1) - df[bands].min(axis=1)
    df["mag_mean_x_redshift"] = df["mag_mean"] * df["redshift"]
    

    return df


def prepare_features(train_df, test_df):
    train_df = add_basic_features(train_df)
    test_df = add_basic_features(test_df)

    features = [c for c in train_df.columns if c not in [id_col, target_col]]
    all_df = pd.concat([train_df[features], test_df[features]], axis=0, ignore_index=True)

    cat_cols = [c for c in features if all_df[c].dtype == "object" or str(all_df[c].dtype) == "category"]
    num_cols = [c for c in features if c not in cat_cols]

    for c in num_cols:
        median = all_df[c].median()
        train_df[c] = train_df[c].fillna(median)
        test_df[c] = test_df[c].fillna(median)

    for c in cat_cols:
        train_df[c] = train_df[c].astype("string").fillna("__MISSING__")
        test_df[c] = test_df[c].astype("string").fillna("__MISSING__")

        cats = pd.Index(pd.concat([train_df[c], test_df[c]], axis=0).unique())
        train_df[c] = pd.Categorical(train_df[c], categories=cats)
        test_df[c] = pd.Categorical(test_df[c], categories=cats)

    return train_df, test_df, features, cat_cols


train_fe, test_fe, features, cat_cols = prepare_features(train, test)

print("n_features:", len(features))
print("categorical:", cat_cols)
# Out:
# n_features: 27
# categorical: ['spectral_type', 'galaxy_population']

# %% [markdown]
# ## 4. Validation

# %%
def encode_target(values):
    classes = pd.Index(pd.unique(values))
    class_to_id = {label: i for i, label in enumerate(classes)}
    encoded = pd.Series(values).map(class_to_id).to_numpy()
    return encoded, classes


def make_stratified_folds(y, n_splits, seed):
    rng = np.random.default_rng(seed)
    fold_indices = [[] for _ in range(n_splits)]

    for cls in np.unique(y):
        cls_idx = np.where(y == cls)[0]
        rng.shuffle(cls_idx)
        for fold, part in enumerate(np.array_split(cls_idx, n_splits)):
            fold_indices[fold].extend(part.tolist())

    all_idx = np.arange(len(y))
    folds = []
    for valid_idx in fold_indices:
        valid_idx = np.array(sorted(valid_idx))
        train_idx = np.setdiff1d(all_idx, valid_idx)
        folds.append((train_idx, valid_idx))
    return folds


def accuracy(y_true, proba):
    return float((y_true == proba.argmax(axis=1)).mean())


def multiclass_log_loss(y_true, proba):
    proba = np.clip(proba, 1e-15, 1 - 1e-15)
    return float(-np.mean(np.log(proba[np.arange(len(y_true)), y_true])))


y, classes = encode_target(train_fe[target_col])
n_classes = len(classes)
folds = make_stratified_folds(y, CFG.n_splits, CFG.seed)

print("classes:", list(classes))
print("folds:", len(folds))
# Out:
# classes: ['GALAXY', 'QSO', 'STAR']
# folds: 5

# %% [markdown]
# ## 5. Training

# %%
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier, Pool


def encode_categoricals(df):
    out = df.copy()
    for c in cat_cols:
        out[c] = out[c].cat.codes.astype("int32")
    return out


def train_lgbm_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    params = CFG.lgbm_params.copy()
    params["num_class"] = n_classes

    train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=cat_cols, free_raw_data=False)
    valid_data = lgb.Dataset(X_valid, label=y_valid, categorical_feature=cat_cols, free_raw_data=False)

    model = lgb.train(
        params,
        train_data,
        num_boost_round=CFG.num_boost_round,
        valid_sets=[valid_data],
        valid_names=["valid"],
        callbacks=[
            lgb.early_stopping(CFG.early_stopping_rounds, verbose=False),
            lgb.log_evaluation(CFG.verbose_eval),
        ],
    )
    valid_pred = model.predict(X_valid, num_iteration=model.best_iteration)
    test_pred = model.predict(X_test, num_iteration=model.best_iteration)
    return model, valid_pred, test_pred, model.best_iteration


def train_xgb_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    params = CFG.xgb_params.copy()
    params["num_class"] = n_classes

    X_train_xgb = encode_categoricals(X_train)
    X_valid_xgb = encode_categoricals(X_valid)
    X_test_xgb = encode_categoricals(X_test)

    dtrain = xgb.DMatrix(X_train_xgb, label=y_train)
    dvalid = xgb.DMatrix(X_valid_xgb, label=y_valid)
    dtest = xgb.DMatrix(X_test_xgb)

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=CFG.num_boost_round,
        evals=[(dvalid, "valid")],
        early_stopping_rounds=CFG.early_stopping_rounds,
        verbose_eval=CFG.verbose_eval,
    )
    valid_pred = model.predict(dvalid, iteration_range=(0, model.best_iteration + 1))
    test_pred = model.predict(dtest, iteration_range=(0, model.best_iteration + 1))
    return model, valid_pred, test_pred, model.best_iteration


def to_catboost_frame(df):
    out = df.copy()
    for c in cat_cols:
        out[c] = out[c].astype(str)
    return out


def train_cat_fold(X_train, y_train, X_valid, y_valid, X_test):
    # Future extraction point: src/train.py
    cat_features = [X_train.columns.get_loc(c) for c in cat_cols]

    X_train_cat = to_catboost_frame(X_train)
    X_valid_cat = to_catboost_frame(X_valid)
    X_test_cat = to_catboost_frame(X_test)

    train_pool = Pool(X_train_cat, y_train, cat_features=cat_features)
    valid_pool = Pool(X_valid_cat, y_valid, cat_features=cat_features)
    test_pool = Pool(X_test_cat, cat_features=cat_features)

    model = CatBoostClassifier(**CFG.cat_params)
    model.fit(
        train_pool,
        eval_set=valid_pool,
        early_stopping_rounds=CFG.early_stopping_rounds,
        use_best_model=True,
    )
    valid_pred = model.predict_proba(valid_pool)
    test_pred = model.predict_proba(test_pool)
    return model, valid_pred, test_pred, model.get_best_iteration()


def train_model(model_name):
    oof = np.zeros((len(train_fe), n_classes), dtype=np.float32)
    test_pred = np.zeros((len(test_fe), n_classes), dtype=np.float32)
    fold_logs = []

    print(f"\n===== {model_name} =====")
    for fold, (tr_idx, va_idx) in enumerate(folds, 1):
        X_tr = train_fe.iloc[tr_idx][features]
        y_tr = y[tr_idx]
        X_va = train_fe.iloc[va_idx][features]
        y_va = y[va_idx]
        X_te = test_fe[features]

        if model_name == "lgbm":
            model, valid_pred, test_fold_pred, best_iteration = train_lgbm_fold(X_tr, y_tr, X_va, y_va, X_te)
        elif model_name == "xgb":
            model, valid_pred, test_fold_pred, best_iteration = train_xgb_fold(X_tr, y_tr, X_va, y_va, X_te)
        elif model_name == "cat":
            model, valid_pred, test_fold_pred, best_iteration = train_cat_fold(X_tr, y_tr, X_va, y_va, X_te)
        else:
            raise ValueError(f"Unknown model: {model_name}")

        oof[va_idx] = valid_pred
        test_pred += test_fold_pred / CFG.n_splits

        fold_acc = accuracy(y_va, valid_pred)
        fold_ll = multiclass_log_loss(y_va, valid_pred)
        fold_logs.append({
            "fold": fold,
            "accuracy": fold_acc,
            "logloss": fold_ll,
            "best_iteration": int(best_iteration) if best_iteration is not None else None,
        })
        print(f"{model_name} fold {fold}: accuracy={fold_acc:.6f}, logloss={fold_ll:.6f}, best_iteration={best_iteration}")

        del model, X_tr, X_va, X_te
        gc.collect()

    cv_acc = accuracy(y, oof)
    cv_ll = multiclass_log_loss(y, oof)
    print(f"{model_name} CV: accuracy={cv_acc:.6f}, logloss={cv_ll:.6f}")

    return {
        "name": model_name,
        "oof": oof,
        "test_pred": test_pred,
        "cv_accuracy": cv_acc,
        "cv_logloss": cv_ll,
        "folds": fold_logs,
    }


model_results = []
for model_name in CFG.models:
    model_results.append(train_model(model_name))
# Out:
# ===== lgbm =====
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [100]	valid's multi_logloss: 0.115131
# [200]	valid's multi_logloss: 0.0931696
# [300]	valid's multi_logloss: 0.0893422
# [400]	valid's multi_logloss: 0.0878994
# [500]	valid's multi_logloss: 0.0870108
# [600]	valid's multi_logloss: 0.0864993
# [700]	valid's multi_logloss: 0.0861031
# [800]	valid's multi_logloss: 0.0858346
# [900]	valid's multi_logloss: 0.0856653
# [1000]	valid's multi_logloss: 0.0855411
# [1100]	valid's multi_logloss: 0.0854435
# [1200]	valid's multi_logloss: 0.0854574
# [1300]	valid's multi_logloss: 0.0854311
# [1400]	valid's multi_logloss: 0.0853864
# [1500]	valid's multi_logloss: 0.0854003
# lgbm fold 1: accuracy=0.969291, logloss=0.085373, best_iteration=1411
# [100]	valid's multi_logloss: 0.114378
# [200]	valid's multi_logloss: 0.0928362
# [300]	valid's multi_logloss: 0.0893219
# [400]	valid's multi_logloss: 0.0880377
# [500]	valid's multi_logloss: 0.0871743
# [600]	valid's multi_logloss: 0.0867162
# [700]	valid's multi_logloss: 0.086372
# [800]	valid's multi_logloss: 0.0860723
# [900]	valid's multi_logloss: 0.0858473
# [1000]	valid's multi_logloss: 0.0857356
# [1100]	valid's multi_logloss: 0.0856638
# [1200]	valid's multi_logloss: 0.0855944
# lgbm fold 2: accuracy=0.969568, logloss=0.085581, best_iteration=1171
# [100]	valid's multi_logloss: 0.116615
# [200]	valid's multi_logloss: 0.0945252
# [300]	valid's multi_logloss: 0.0906552
# [400]	valid's multi_logloss: 0.089006
# [500]	valid's multi_logloss: 0.0881352
# [600]	valid's multi_logloss: 0.0876281
# [700]	valid's multi_logloss: 0.0871375
# [800]	valid's multi_logloss: 0.0868439
# [900]	valid's multi_logloss: 0.0866537
# [1000]	valid's multi_logloss: 0.0865388
# [1100]	valid's multi_logloss: 0.0864685
# [1200]	valid's multi_logloss: 0.0864451
# [1300]	valid's multi_logloss: 0.086446
# lgbm fold 3: accuracy=0.968667, logloss=0.086412, best_iteration=1253
# [100]	valid's multi_logloss: 0.117277
# [200]	valid's multi_logloss: 0.0963103
# [300]	valid's multi_logloss: 0.092831
# [400]	valid's multi_logloss: 0.0916176
# [500]	valid's multi_logloss: 0.0908239
# [600]	valid's multi_logloss: 0.0902589
# [700]	valid's multi_logloss: 0.0899201
# [800]	valid's multi_logloss: 0.0896748
# [900]	valid's multi_logloss: 0.0895256
# [1000]	valid's multi_logloss: 0.08939
# [1100]	valid's multi_logloss: 0.08934
# [1200]	valid's multi_logloss: 0.0893306
# lgbm fold 4: accuracy=0.968554, logloss=0.089303, best_iteration=1129
# [100]	valid's multi_logloss: 0.116261
# [200]	valid's multi_logloss: 0.0940027
# [300]	valid's multi_logloss: 0.0902439
# [400]	valid's multi_logloss: 0.0887646
# [500]	valid's multi_logloss: 0.0879508
# [600]	valid's multi_logloss: 0.0873689
# [700]	valid's multi_logloss: 0.0870911
# [800]	valid's multi_logloss: 0.0868772
# [900]	valid's multi_logloss: 0.0867087
# [1000]	valid's multi_logloss: 0.0866405
# [1100]	valid's multi_logloss: 0.086554
# [1200]	valid's multi_logloss: 0.0865071
# lgbm fold 5: accuracy=0.969100, logloss=0.086492, best_iteration=1183
# lgbm CV: accuracy=0.969036, logloss=0.086632
#
# ===== xgb =====
# [0]	valid-mlogloss:0.84251
# [100]	valid-mlogloss:0.13648
# [200]	valid-mlogloss:0.10379
# [300]	valid-mlogloss:0.09641
# [400]	valid-mlogloss:0.09306
# [500]	valid-mlogloss:0.09069
# [600]	valid-mlogloss:0.08903
# [700]	valid-mlogloss:0.08791
# [800]	valid-mlogloss:0.08718
# [900]	valid-mlogloss:0.08664
# [1000]	valid-mlogloss:0.08627
# [1100]	valid-mlogloss:0.08598
# [1200]	valid-mlogloss:0.08575
# [1300]	valid-mlogloss:0.08561
# [1400]	valid-mlogloss:0.08554
# [1500]	valid-mlogloss:0.08548
# [1600]	valid-mlogloss:0.08541
# [1700]	valid-mlogloss:0.08538
# [1748]	valid-mlogloss:0.08537
# xgb fold 1: accuracy=0.969481, logloss=0.085365, best_iteration=1648
# [0]	valid-mlogloss:0.84251
# [100]	valid-mlogloss:0.13553
# [200]	valid-mlogloss:0.10274
# [300]	valid-mlogloss:0.09580
# [400]	valid-mlogloss:0.09257
# [500]	valid-mlogloss:0.09017
# [600]	valid-mlogloss:0.08873
# [700]	valid-mlogloss:0.08781
# [800]	valid-mlogloss:0.08718
# [900]	valid-mlogloss:0.08667
# [1000]	valid-mlogloss:0.08637
# [1100]	valid-mlogloss:0.08610
# [1200]	valid-mlogloss:0.08594
# [1300]	valid-mlogloss:0.08584
# [1400]	valid-mlogloss:0.08577
# [1500]	valid-mlogloss:0.08575
# [1600]	valid-mlogloss:0.08574
# [1662]	valid-mlogloss:0.08576
# xgb fold 2: accuracy=0.969836, logloss=0.085708, best_iteration=1562
# [0]	valid-mlogloss:0.84258
# [100]	valid-mlogloss:0.13818
# [200]	valid-mlogloss:0.10534
# [300]	valid-mlogloss:0.09816
# [400]	valid-mlogloss:0.09453
# [500]	valid-mlogloss:0.09192
# [600]	valid-mlogloss:0.09021
# [700]	valid-mlogloss:0.08918
# [800]	valid-mlogloss:0.08847
# [900]	valid-mlogloss:0.08793
# [1000]	valid-mlogloss:0.08755
# [1100]	valid-mlogloss:0.08723
# [1200]	valid-mlogloss:0.08699
# [1300]	valid-mlogloss:0.08681
# [1400]	valid-mlogloss:0.08673
# [1500]	valid-mlogloss:0.08665
# [1600]	valid-mlogloss:0.08662
# [1700]	valid-mlogloss:0.08666
# xgb fold 3: accuracy=0.968650, logloss=0.086624, best_iteration=1600
# [0]	valid-mlogloss:0.84258
# [100]	valid-mlogloss:0.13847
# [200]	valid-mlogloss:0.10651
# [300]	valid-mlogloss:0.09953
# [400]	valid-mlogloss:0.09621
# [500]	valid-mlogloss:0.09397
# [600]	valid-mlogloss:0.09255
# [700]	valid-mlogloss:0.09172
# [800]	valid-mlogloss:0.09108
# [900]	valid-mlogloss:0.09061
# [1000]	valid-mlogloss:0.09027
# [1100]	valid-mlogloss:0.09002
# [1200]	valid-mlogloss:0.08991
# [1300]	valid-mlogloss:0.08979
# [1400]	valid-mlogloss:0.08975
# [1447]	valid-mlogloss:0.08975
# xgb fold 4: accuracy=0.968745, logloss=0.089726, best_iteration=1347
# [0]	valid-mlogloss:0.84265
# [100]	valid-mlogloss:0.13741
# [200]	valid-mlogloss:0.10415
# [300]	valid-mlogloss:0.09688
# [400]	valid-mlogloss:0.09346
# [500]	valid-mlogloss:0.09100
# [600]	valid-mlogloss:0.08942
# [700]	valid-mlogloss:0.08835
# [800]	valid-mlogloss:0.08765
# [900]	valid-mlogloss:0.08717
# [1000]	valid-mlogloss:0.08685
# [1100]	valid-mlogloss:0.08658
# [1200]	valid-mlogloss:0.08641
# [1300]	valid-mlogloss:0.08629
# [1400]	valid-mlogloss:0.08618
# [1500]	valid-mlogloss:0.08618
# [1600]	valid-mlogloss:0.08620
# [1620]	valid-mlogloss:0.08621
# xgb fold 5: accuracy=0.969333, logloss=0.086164, best_iteration=1520
# xgb CV: accuracy=0.969209, logloss=0.086718
#
# ===== cat =====
# 0:	learn: 1.0488884	test: 1.0488672	best: 1.0488672 (0)	total: 6.25s	remaining: 8h 41m 1s
# 100:	learn: 0.1645382	test: 0.1639943	best: 0.1639943 (100)	total: 10.3s	remaining: 8m 19s
# 200:	learn: 0.1232665	test: 0.1228650	best: 0.1228650 (200)	total: 14.3s	remaining: 5m 41s
# 300:	learn: 0.1127134	test: 0.1127507	best: 0.1127507 (300)	total: 18.3s	remaining: 4m 45s
# 400:	learn: 0.1069015	test: 0.1074528	best: 0.1074528 (400)	total: 22.4s	remaining: 4m 16s
# 500:	learn: 0.1031022	test: 0.1041454	best: 0.1041454 (500)	total: 26.4s	remaining: 3m 56s
# 600:	learn: 0.1003852	test: 0.1019347	best: 0.1019347 (600)	total: 30.4s	remaining: 3m 42s
# 700:	learn: 0.0982819	test: 0.1003360	best: 0.1003360 (700)	total: 34.5s	remaining: 3m 31s
# 800:	learn: 0.0965749	test: 0.0991425	best: 0.0991425 (800)	total: 38.5s	remaining: 3m 21s
# 900:	learn: 0.0951209	test: 0.0981595	best: 0.0981595 (900)	total: 42.6s	remaining: 3m 14s
# 3700:	learn: 0.0784793	test: 0.0918534	best: 0.0918525 (3698)	total: 2m 35s	remaining: 54.7s
# 3800:	learn: 0.0781180	test: 0.0918026	best: 0.0918022 (3798)	total: 2m 39s	remaining: 50.4s
# 3900:	learn: 0.0777235	test: 0.0917555	best: 0.0917555 (3900)	total: 2m 43s	remaining: 46.1s
# 4000:	learn: 0.0773535	test: 0.0917152	best: 0.0917118 (3991)	total: 2m 47s	remaining: 41.9s
# 4100:	learn: 0.0769958	test: 0.0916526	best: 0.0916524 (4099)	total: 2m 51s	remaining: 37.7s
# 4200:	learn: 0.0766209	test: 0.0915936	best: 0.0915935 (4199)	total: 2m 55s	remaining: 33.4s
# 4300:	learn: 0.0762780	test: 0.0915665	best: 0.0915616 (4283)	total: 2m 59s	remaining: 29.3s
# 4400:	learn: 0.0759348	test: 0.0915345	best: 0.0915336 (4397)	total: 3m 4s	remaining: 25.1s
# 4500:	learn: 0.0755889	test: 0.0914835	best: 0.0914835 (4500)	total: 3m 8s	remaining: 20.9s
# 4600:	learn: 0.0752484	test: 0.0914420	best: 0.0914416 (4599)	total: 3m 12s	remaining: 16.7s
# 4700:	learn: 0.0748741	test: 0.0913737	best: 0.0913737 (4700)	total: 3m 16s	remaining: 12.5s
# 4800:	learn: 0.0745555	test: 0.0913250	best: 0.0913240 (4799)	total: 3m 20s	remaining: 8.3s
# 4900:	learn: 0.0742272	test: 0.0912972	best: 0.0912966 (4899)	total: 3m 24s	remaining: 4.13s
# 4999:	learn: 0.0738911	test: 0.0912571	best: 0.0912553 (4994)	total: 3m 28s	remaining: 0us
# bestTest = 0.09125531287
# bestIteration = 4994
# Shrink model to first 4995 iterations.
# cat fold 1: accuracy=0.967178, logloss=0.091255, best_iteration=4994
# 0:	learn: 1.0490432	test: 1.0489779	best: 1.0489779 (0)	total: 35.9ms	remaining: 2m 59s
# 100:	learn: 0.1643627	test: 0.1628474	best: 0.1628474 (100)	total: 4.13s	remaining: 3m 20s
# 200:	learn: 0.1232577	test: 0.1219873	best: 0.1219873 (200)	total: 8.23s	remaining: 3m 16s
# 300:	learn: 0.1126364	test: 0.1118557	best: 0.1118557 (300)	total: 12.3s	remaining: 3m 12s
# 400:	learn: 0.1069372	test: 0.1067644	best: 0.1067644 (400)	total: 16.4s	remaining: 3m 7s
# 500:	learn: 0.1032257	test: 0.1035932	best: 0.1035932 (500)	total: 20.4s	remaining: 3m 3s
# 600:	learn: 0.1005924	test: 0.1015173	best: 0.1015173 (600)	total: 24.4s	remaining: 2m 58s
# 700:	learn: 0.0984725	test: 0.0998769	best: 0.0998769 (700)	total: 28.5s	remaining: 2m 54s
# 800:	learn: 0.0967729	test: 0.0986623	best: 0.0986623 (800)	total: 32.5s	remaining: 2m 50s
# 900:	learn: 0.0953130	test: 0.0976745	best: 0.0976745 (900)	total: 36.5s	remaining: 2m 46s
# 1000:	learn: 0.0940840	test: 0.0968806	best: 0.0968806 (1000)	total: 40.6s	remaining: 2m 42s
# 3700:	learn: 0.0782759	test: 0.0912592	best: 0.0912592 (3700)	total: 2m 30s	remaining: 52.7s
# 3800:	learn: 0.0779144	test: 0.0912122	best: 0.0912111 (3796)	total: 2m 34s	remaining: 48.7s
# 3900:	learn: 0.0775449	test: 0.0911651	best: 0.0911635 (3899)	total: 2m 38s	remaining: 44.6s
# 4000:	learn: 0.0771565	test: 0.0911135	best: 0.0911115 (3998)	total: 2m 42s	remaining: 40.6s
# 4100:	learn: 0.0767871	test: 0.0910677	best: 0.0910677 (4100)	total: 2m 46s	remaining: 36.5s
# 4200:	learn: 0.0764147	test: 0.0909991	best: 0.0909983 (4197)	total: 2m 50s	remaining: 32.5s
# 4300:	learn: 0.0760645	test: 0.0909625	best: 0.0909625 (4300)	total: 2m 54s	remaining: 28.4s
# 4400:	learn: 0.0757247	test: 0.0909203	best: 0.0909203 (4400)	total: 2m 58s	remaining: 24.3s
# 4500:	learn: 0.0753271	test: 0.0908557	best: 0.0908540 (4489)	total: 3m 2s	remaining: 20.3s
# 4600:	learn: 0.0749944	test: 0.0908292	best: 0.0908292 (4600)	total: 3m 7s	remaining: 16.2s
# 4700:	learn: 0.0746637	test: 0.0907884	best: 0.0907860 (4696)	total: 3m 11s	remaining: 12.2s
# 4800:	learn: 0.0743345	test: 0.0907559	best: 0.0907534 (4797)	total: 3m 15s	remaining: 8.08s
# 4900:	learn: 0.0739920	test: 0.0907149	best: 0.0907148 (4895)	total: 3m 19s	remaining: 4.02s
# 4999:	learn: 0.0736470	test: 0.0906536	best: 0.0906536 (4999)	total: 3m 23s	remaining: 0us
# bestTest = 0.09065360253
# bestIteration = 4999
# cat fold 2: accuracy=0.967282, logloss=0.090654, best_iteration=4999
# 0:	learn: 1.0490233	test: 1.0490796	best: 1.0490796 (0)	total: 36.3ms	remaining: 3m 1s
# 100:	learn: 0.1634228	test: 0.1650799	best: 0.1650799 (100)	total: 4.13s	remaining: 3m 20s
# 200:	learn: 0.1228903	test: 0.1250515	best: 0.1250515 (200)	total: 8.13s	remaining: 3m 14s
# 300:	learn: 0.1123922	test: 0.1148321	best: 0.1148321 (300)	total: 12.1s	remaining: 3m 9s
# 400:	learn: 0.1069115	test: 0.1095599	best: 0.1095599 (400)	total: 16.1s	remaining: 3m 4s
# 500:	learn: 0.1031843	test: 0.1062032	best: 0.1062032 (500)	total: 20.2s	remaining: 3m 1s
# 600:	learn: 0.1005906	test: 0.1040142	best: 0.1040142 (600)	total: 24.2s	remaining: 2m 56s
# 700:	learn: 0.0984283	test: 0.1022021	best: 0.1022021 (700)	total: 28.3s	remaining: 2m 53s
# 800:	learn: 0.0966446	test: 0.1007912	best: 0.1007912 (800)	total: 32.3s	remaining: 2m 49s
# 900:	learn: 0.0952257	test: 0.0997648	best: 0.0997648 (900)	total: 36.4s	remaining: 2m 45s
# 1000:	learn: 0.0939928	test: 0.0989653	best: 0.0989653 (1000)	total: 40.5s	remaining: 2m 41s
# 1100:	learn: 0.0929762	test: 0.0983219	best: 0.0983219 (1100)	total: 44.6s	remaining: 2m 37s
# 3800:	learn: 0.0777086	test: 0.0925615	best: 0.0925606 (3799)	total: 2m 35s	remaining: 48.9s
# 3900:	learn: 0.0773314	test: 0.0925185	best: 0.0925184 (3899)	total: 2m 39s	remaining: 44.8s
# 4000:	learn: 0.0769517	test: 0.0924747	best: 0.0924709 (3986)	total: 2m 43s	remaining: 40.8s
# 4100:	learn: 0.0765971	test: 0.0924385	best: 0.0924385 (4100)	total: 2m 47s	remaining: 36.7s
# 4200:	learn: 0.0762099	test: 0.0923763	best: 0.0923743 (4181)	total: 2m 51s	remaining: 32.6s
# 4300:	learn: 0.0758487	test: 0.0922961	best: 0.0922925 (4297)	total: 2m 55s	remaining: 28.5s
# 4400:	learn: 0.0754881	test: 0.0922303	best: 0.0922303 (4400)	total: 2m 59s	remaining: 24.5s
# 4500:	learn: 0.0751330	test: 0.0921740	best: 0.0921740 (4500)	total: 3m 3s	remaining: 20.4s
# 4600:	learn: 0.0747958	test: 0.0921225	best: 0.0921225 (4600)	total: 3m 7s	remaining: 16.3s
# 4700:	learn: 0.0744518	test: 0.0920856	best: 0.0920856 (4700)	total: 3m 11s	remaining: 12.2s
# 4800:	learn: 0.0741116	test: 0.0920535	best: 0.0920513 (4796)	total: 3m 15s	remaining: 8.12s
# 4900:	learn: 0.0737489	test: 0.0920210	best: 0.0920210 (4900)	total: 3m 19s	remaining: 4.04s
# 4999:	learn: 0.0734273	test: 0.0919946	best: 0.0919893 (4975)	total: 3m 24s	remaining: 0us
# bestTest = 0.09198932894
# bestIteration = 4975
# Shrink model to first 4976 iterations.
# cat fold 3: accuracy=0.966104, logloss=0.091989, best_iteration=4975
# 0:	learn: 1.0489320	test: 1.0489343	best: 1.0489343 (0)	total: 36.7ms	remaining: 3m 3s
# 100:	learn: 0.1639135	test: 0.1652379	best: 0.1652379 (100)	total: 4.15s	remaining: 3m 21s
# 200:	learn: 0.1228167	test: 0.1253384	best: 0.1253384 (200)	total: 8.21s	remaining: 3m 15s
# 300:	learn: 0.1121732	test: 0.1153610	best: 0.1153610 (300)	total: 12.2s	remaining: 3m 11s
# 400:	learn: 0.1065894	test: 0.1102934	best: 0.1102934 (400)	total: 16.4s	remaining: 3m 7s
# 500:	learn: 0.1028010	test: 0.1070332	best: 0.1070332 (500)	total: 20.4s	remaining: 3m 3s
# 600:	learn: 0.0999741	test: 0.1046609	best: 0.1046609 (600)	total: 24.6s	remaining: 2m 59s
# 700:	learn: 0.0977937	test: 0.1029881	best: 0.1029881 (700)	total: 28.7s	remaining: 2m 56s
# 800:	learn: 0.0959822	test: 0.1016297	best: 0.1016297 (800)	total: 32.8s	remaining: 2m 51s
# 900:	learn: 0.0945982	test: 0.1007043	best: 0.1007043 (900)	total: 36.9s	remaining: 2m 47s
# 1000:	learn: 0.0933352	test: 0.0998546	best: 0.0998546 (1000)	total: 41s	remaining: 2m 43s
# 1100:	learn: 0.0922413	test: 0.0991645	best: 0.0991645 (1100)	total: 45s	remaining: 2m 39s
# 3800:	learn: 0.0769887	test: 0.0941649	best: 0.0941621 (3790)	total: 2m 35s	remaining: 49s
# 3900:	learn: 0.0766339	test: 0.0941212	best: 0.0941212 (3900)	total: 2m 39s	remaining: 44.9s
# 4000:	learn: 0.0762471	test: 0.0940746	best: 0.0940746 (4000)	total: 2m 43s	remaining: 40.8s
# 4100:	learn: 0.0758814	test: 0.0940282	best: 0.0940259 (4094)	total: 2m 47s	remaining: 36.7s
# 4200:	learn: 0.0755001	test: 0.0939728	best: 0.0939721 (4198)	total: 2m 51s	remaining: 32.7s
# 4300:	learn: 0.0751309	test: 0.0939291	best: 0.0939291 (4300)	total: 2m 56s	remaining: 28.6s
# 4400:	learn: 0.0747675	test: 0.0938897	best: 0.0938867 (4389)	total: 3m	remaining: 24.5s
# 4500:	learn: 0.0744425	test: 0.0938859	best: 0.0938751 (4440)	total: 3m 4s	remaining: 20.4s
# bestTest = 0.0938750843
# bestIteration = 4440
# Shrink model to first 4441 iterations.
# cat fold 4: accuracy=0.966710, logloss=0.093875, best_iteration=4440
# 0:	learn: 1.0488134	test: 1.0489111	best: 1.0489111 (0)	total: 35.9ms	remaining: 2m 59s
# 100:	learn: 0.1633988	test: 0.1652069	best: 0.1652069 (100)	total: 4.18s	remaining: 3m 22s
# 200:	learn: 0.1227872	test: 0.1246492	best: 0.1246492 (200)	total: 8.25s	remaining: 3m 16s
# 300:	learn: 0.1122177	test: 0.1141351	best: 0.1141351 (300)	total: 12.3s	remaining: 3m 11s
# 400:	learn: 0.1066968	test: 0.1088641	best: 0.1088641 (400)	total: 16.4s	remaining: 3m 7s
# 500:	learn: 0.1030739	test: 0.1055402	best: 0.1055402 (500)	total: 20.4s	remaining: 3m 2s
# 600:	learn: 0.1002267	test: 0.1031145	best: 0.1031145 (600)	total: 24.4s	remaining: 2m 58s
# 700:	learn: 0.0981557	test: 0.1013984	best: 0.1013984 (700)	total: 28.4s	remaining: 2m 54s
# 800:	learn: 0.0964307	test: 0.1000947	best: 0.1000947 (800)	total: 32.5s	remaining: 2m 50s
# 900:	learn: 0.0950489	test: 0.0990999	best: 0.0990999 (900)	total: 36.5s	remaining: 2m 46s
# 1000:	learn: 0.0938225	test: 0.0982982	best: 0.0982982 (1000)	total: 40.6s	remaining: 2m 42s
# 1100:	learn: 0.0927380	test: 0.0976002	best: 0.0976002 (1100)	total: 44.7s	remaining: 2m 38s
# 1200:	learn: 0.0918133	test: 0.0970793	best: 0.0970793 (1200)	total: 48.7s	remaining: 2m 34s
# 1300:	learn: 0.0908854	test: 0.0965399	best: 0.0965399 (1300)	total: 52.7s	remaining: 2m 29s
# 1400:	learn: 0.0900758	test: 0.0961393	best: 0.0961393 (1400)	total: 56.9s	remaining: 2m 26s
# 1500:	learn: 0.0893268	test: 0.0957695	best: 0.0957695 (1500)	total: 1m	remaining: 2m 22s
# 1600:	learn: 0.0885839	test: 0.0954062	best: 0.0954062 (1600)	total: 1m 5s	remaining: 2m 18s
# 1700:	learn: 0.0878815	test: 0.0951053	best: 0.0951053 (1700)	total: 1m 9s	remaining: 2m 13s
# 1800:	learn: 0.0872564	test: 0.0948441	best: 0.0948441 (1800)	total: 1m 13s	remaining: 2m 9s
# 1900:	learn: 0.0866519	test: 0.0946216	best: 0.0946216 (1900)	total: 1m 17s	remaining: 2m 5s
# 2000:	learn: 0.0860831	test: 0.0944356	best: 0.0944356 (2000)	total: 1m 21s	remaining: 2m 1s
# 2100:	learn: 0.0854686	test: 0.0941840	best: 0.0941840 (2100)	total: 1m 25s	remaining: 1m 57s
# 2200:	learn: 0.0849473	test: 0.0940191	best: 0.0940191 (2200)	total: 1m 29s	remaining: 1m 53s
# 2300:	learn: 0.0844107	test: 0.0938478	best: 0.0938478 (2300)	total: 1m 33s	remaining: 1m 49s
# 2400:	learn: 0.0839134	test: 0.0937241	best: 0.0937241 (2399)	total: 1m 37s	remaining: 1m 45s
# 2500:	learn: 0.0833951	test: 0.0935450	best: 0.0935450 (2500)	total: 1m 41s	remaining: 1m 41s
# 2600:	learn: 0.0829215	test: 0.0934334	best: 0.0934334 (2600)	total: 1m 45s	remaining: 1m 37s
# 2700:	learn: 0.0824636	test: 0.0933125	best: 0.0933108 (2699)	total: 1m 49s	remaining: 1m 33s
# 2800:	learn: 0.0820055	test: 0.0931950	best: 0.0931947 (2799)	total: 1m 53s	remaining: 1m 29s
# 2900:	learn: 0.0815249	test: 0.0930702	best: 0.0930702 (2900)	total: 1m 57s	remaining: 1m 25s
# 3000:	learn: 0.0810842	test: 0.0929702	best: 0.0929702 (3000)	total: 2m 1s	remaining: 1m 21s
# 3100:	learn: 0.0806369	test: 0.0928657	best: 0.0928657 (3100)	total: 2m 5s	remaining: 1m 17s
# 3200:	learn: 0.0802182	test: 0.0928000	best: 0.0928000 (3200)	total: 2m 10s	remaining: 1m 13s
# 3300:	learn: 0.0798334	test: 0.0927318	best: 0.0927318 (3300)	total: 2m 14s	remaining: 1m 9s
# 3400:	learn: 0.0794174	test: 0.0926539	best: 0.0926536 (3399)	total: 2m 18s	remaining: 1m 4s
# 3500:	learn: 0.0789794	test: 0.0925476	best: 0.0925476 (3500)	total: 2m 22s	remaining: 1m
# 3600:	learn: 0.0785959	test: 0.0924933	best: 0.0924919 (3597)	total: 2m 26s	remaining: 56.9s
# 3700:	learn: 0.0781930	test: 0.0924346	best: 0.0924346 (3700)	total: 2m 30s	remaining: 52.8s
# 3800:	learn: 0.0778074	test: 0.0923894	best: 0.0923876 (3797)	total: 2m 34s	remaining: 48.7s
# 3900:	learn: 0.0774248	test: 0.0923350	best: 0.0923350 (3900)	total: 2m 38s	remaining: 44.7s
# 4000:	learn: 0.0770730	test: 0.0922989	best: 0.0922989 (4000)	total: 2m 42s	remaining: 40.6s
# 4100:	learn: 0.0767296	test: 0.0922515	best: 0.0922502 (4094)	total: 2m 46s	remaining: 36.5s
# 4200:	learn: 0.0763578	test: 0.0921716	best: 0.0921715 (4198)	total: 2m 50s	remaining: 32.5s
# 4300:	learn: 0.0760149	test: 0.0921319	best: 0.0921301 (4295)	total: 2m 54s	remaining: 28.4s
# 4400:	learn: 0.0756469	test: 0.0920868	best: 0.0920868 (4400)	total: 2m 58s	remaining: 24.3s
# 4500:	learn: 0.0752821	test: 0.0920223	best: 0.0920223 (4500)	total: 3m 2s	remaining: 20.3s
# 4600:	learn: 0.0749265	test: 0.0919702	best: 0.0919654 (4590)	total: 3m 7s	remaining: 16.2s
# 4700:	learn: 0.0745897	test: 0.0919108	best: 0.0919102 (4695)	total: 3m 11s	remaining: 12.2s
# 4800:	learn: 0.0742525	test: 0.0918610	best: 0.0918602 (4783)	total: 3m 15s	remaining: 8.09s
# 4900:	learn: 0.0738964	test: 0.0918117	best: 0.0918117 (4900)	total: 3m 19s	remaining: 4.03s
# 4999:	learn: 0.0735748	test: 0.0918101	best: 0.0918082 (4925)	total: 3m 23s	remaining: 0us
# bestTest = 0.09180818258
# bestIteration = 4925
# Shrink model to first 4926 iterations.
# cat fold 5: accuracy=0.966839, logloss=0.091808, best_iteration=4925
# cat CV: accuracy=0.966822, logloss=0.091916

# %% [markdown]
# ## 6. Inference

# %%
if CFG.model_weights is None:
    weights = np.ones(len(model_results), dtype=np.float32) / len(model_results)
else:
    weights = np.array(CFG.model_weights, dtype=np.float32)
    weights = weights / weights.sum()

model_names = [result["name"] for result in model_results]
oof_proba = sum(w * result["oof"] for w, result in zip(weights, model_results))
test_proba = sum(w * result["test_pred"] for w, result in zip(weights, model_results))

cv_acc = accuracy(y, oof_proba)
cv_ll = multiclass_log_loss(y, oof_proba)

test_pred = classes.to_numpy()[test_proba.argmax(axis=1)]
pred_distribution = pd.Series(test_pred).value_counts(normalize=True).sort_index()

print("models:", model_names)
print("weights:", dict(zip(model_names, weights)))
print(f"ensemble CV: accuracy={cv_acc:.6f}, logloss={cv_ll:.6f}")
print(pred_distribution)
# Out:
# models: ['lgbm', 'xgb', 'cat']
# weights: {'lgbm': np.float32(0.33333334), 'xgb': np.float32(0.33333334), 'cat': np.float32(0.33333334)}
# ensemble CV: accuracy=0.968934, logloss=0.087038
# GALAXY    0.655227
# QSO       0.202158
# STAR      0.142615
# Name: proportion, dtype: float64

# %% [markdown]
# ## 7. Submission

# %%
submission = sample_submission.copy()
submission[target_col] = test_pred
submission.to_csv(CFG.output_path, index=False)

experiment_log = {
    "competition": CFG.competition,
    "exp_id": CFG.exp_id,
    "parent_exp_id": CFG.parent_exp_id,
    "note": CFG.note,
    "seed": CFG.seed,
    "n_splits": CFG.n_splits,
    "models": model_names,
    "model_weights": dict(zip(model_names, [float(w) for w in weights])),
    "model_scores": [
        {
            "name": result["name"],
            "cv_accuracy": float(result["cv_accuracy"]),
            "cv_logloss": float(result["cv_logloss"]),
            "folds": result["folds"],
        }
        for result in model_results
    ],
    "ensemble_cv_accuracy": float(cv_acc),
    "ensemble_cv_logloss": float(cv_ll),
    "n_features": len(features),
    "categorical_features": cat_cols,
    "gpu_settings": {
        "lgbm_device": CFG.lgbm_params.get("device"),
        "xgb_device": CFG.xgb_params.get("device"),
        "cat_task_type": CFG.cat_params.get("task_type"),
    },
    "output_path": str(CFG.output_path),
}

print(submission.head())
print("saved:", CFG.output_path)
experiment_log
# Out:
#        id   class
# 0  577347  GALAXY
# 1  577348  GALAXY
# 2  577349  GALAXY
# 3  577350    STAR
# 4  577351  GALAXY
# saved: submission.csv
# {'competition': 'playground-series-s6e6',
#  'exp_id': 'exp_009_add-brightness-redshift-ratio',
#  'parent_exp_id': 'exp_007_remove-cat-boost-and-xgb',
#  'note': 'Remove vectorisation: x, y, z: coordinate',
#  'seed': 42,
#  'n_splits': 5,
#  'models': ['lgbm', 'xgb', 'cat'],
#  'model_weights': {'lgbm': 0.3333333432674408,
#   'xgb': 0.3333333432674408,
#   'cat': 0.3333333432674408},
#  'model_scores': [{'name': 'lgbm',
#    'cv_accuracy': 0.9690359523821895,
#    'cv_logloss': 0.08663205802440643,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9692907248636009,
#      'logloss': 0.08537250432457995,
#      'best_iteration': 1411},
#     {'fold': 2,
#      'accuracy': 0.969567853122023,
#      'logloss': 0.08558073578773202,
#      'best_iteration': 1171},
#     {'fold': 3,
#      'accuracy': 0.9686671862821512,
#      'logloss': 0.0864122959746207,
#      'best_iteration': 1253},
#     {'fold': 4,
#      'accuracy': 0.9685543305995549,
#      'logloss': 0.08930310796856629,
#      'best_iteration': 1129},
#     {'fold': 5,
#      'accuracy': 0.9690996639761665,
#      'logloss': 0.08649164935319277,
#      'best_iteration': 1183}]},
#   {'name': 'xgb',
#    'cv_accuracy': 0.9692091584437089,
#    'cv_logloss': 0.08671755343675613,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9694812505412661,
#      'logloss': 0.08536545187234879,
#      'best_iteration': 1648},
#     {'fold': 2,
#      'accuracy': 0.9698363211223694,
#      'logloss': 0.08570847660303116,
#      'best_iteration': 1562},
#     {'fold': 3,
#      'accuracy': 0.9686498657659999,
#      'logloss': 0.08662374317646027,
#      'best_iteration': 1600},
#     {'fold': 4,
#      'accuracy': 0.9687448579272359,
#      'logloss': 0.08972597867250443,
#      'best_iteration': 1347},
#     {'fold': 5,
#      'accuracy': 0.9693334949942841,
#      'logloss': 0.08616413176059723,
#      'best_iteration': 1520}]},
#   {'name': 'cat',
#    'cv_accuracy': 0.9668223789159726,
#    'cv_logloss': 0.09191624820232391,
#    'folds': [{'fold': 1,
#      'accuracy': 0.9671776218931324,
#      'logloss': 0.09125529642804506,
#      'best_iteration': 4994},
#     {'fold': 2,
#      'accuracy': 0.9672815449900407,
#      'logloss': 0.09065356097247605,
#      'best_iteration': 4999},
#     {'fold': 3,
#      'accuracy': 0.9661037498917467,
#      'logloss': 0.09198928242784438,
#      'best_iteration': 4975},
#     {'fold': 4,
#      'accuracy': 0.9667096796542795,
#      'logloss': 0.09387499177094756,
#      'best_iteration': 4440},
#     {'fold': 5,
#      'accuracy': 0.9668392974676967,
#      'logloss': 0.09180814365273214,
#      'best_iteration': 4925}]}],
#  'ensemble_cv_accuracy': 0.9689337608058932,
#  'ensemble_cv_logloss': 0.08703809231519699,
#  'n_features': 27,
#  'categorical_features': ['spectral_type', 'galaxy_population'],
#  'gpu_settings': {'lgbm_device': 'gpu',
#   'xgb_device': 'cuda',
#   'cat_task_type': 'GPU'},
#  'output_path': 'submission.csv'}
